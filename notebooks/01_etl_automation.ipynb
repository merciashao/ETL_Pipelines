# %%
from etl.download_file import download_file

# %%
download_file(
    url = "https://data.moa.gov.tw/OpenData/GetOpenDataFile.aspx?id=J28&FileType=SHP&RID=41834",
    folder="~/Downloads",
    filename="113年度農村再生社區範圍圖UTF-8.zip"
)
# Out:
# ...
# File successfully downloaded to: /home/yishaolee/Downloads/113年度農村再生社區範圍圖UTF-8.zip
